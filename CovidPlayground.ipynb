# %%
import pandas as pd

# %%
#This first csv contains way more data columns related to diabetes, life expectancy etc.than needed and is super huge; the one that is uncommented contains very precise data
#df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")
df = pd.read_csv("https://covid.ourworldindata.org/data/ecdc/full_data.csv")
countries = pd.read_csv("countries.csv")

# %%
a = countries['name'].unique().tolist()
b = df['location'].unique().tolist()


exclude_list = [i for i in b if i not in a]

#only including the countries for which we have the lat and long for
for i in exclude_list:
    df = df[df['location'] != i]

# %%
#getting the lat and long for the countries
lat = [countries[countries['name'] == i]['latitude'].item() for i in df['location']]
long = [countries[countries['name'] == i]['longitude'].item() for i in df['location']]
# Out:
# C:\Users\sakth\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `item` has been deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# C:\Users\sakth\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `item` has been deprecated and will be removed in a future version

# %%
#accordingly appending it in our df 
df['Long'] = long
df['Lat'] = lat

# %%
df
# Out:
#              date     location  new_cases  new_deaths  total_cases  \
# 0      2019-12-31  Afghanistan        0.0         0.0          0.0
# 1      2020-01-01  Afghanistan        0.0         0.0          0.0
# 2      2020-01-02  Afghanistan        0.0         0.0          0.0
# 3      2020-01-03  Afghanistan        0.0         0.0          0.0
# 4      2020-01-04  Afghanistan        0.0         0.0          0.0
# ...           ...          ...        ...         ...          ...
# 36953  2020-08-11     Zimbabwe       99.0         0.0       4748.0
# 36954  2020-08-12     Zimbabwe       70.0         0.0       4818.0
# 36955  2020-08-13     Zimbabwe       75.0        18.0       4893.0
# 36956  2020-08-14     Zimbabwe       97.0         6.0       4990.0
# 36957  2020-08-15     Zimbabwe       82.0         0.0       5072.0
#
#        total_deaths  weekly_cases  weekly_deaths  biweekly_cases  \
# 0               0.0           NaN            NaN             NaN
# ...
